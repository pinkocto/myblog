# %% [raw]
# ---
# title: "github 연동"
# author: "jiyun Lim"
# date: "03/09/2023"
# categories:
#   - Tip
# ---

# %% [markdown]
# 한글설정은 건너뛰어도 된다.

# %% [markdown]
# `-` [NVIDIA 공식홈페이지](https://www.nvidia.com/en-us/geforce/drivers/) 에서 드라이브 설치파일 다운로드

# %% [markdown]
# ![image.png](attachment:a310d637-2a7e-4957-ac12-020c632eb002.png)
